# %% [markdown]
# ## Klasifikasi

# %% [markdown]
# Klasifikasi yang dilakukan adalah dengan pendekatan Lexicon dengan library dari Bing Liu yang di traslate dalam bahasa Indonesia

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("../data/dataset/datasetpraproses.csv", sep=';')

# %%
dataset
# Out:
#                                                  Tweet                 label  \
# 0    Min, normal ke kalau iPhone 11/11 Pro /Pro Max...       baterai negatif
# 1                           Kmera iphone 11 mmeng beda        kamera positif
# 2    Iphone 11 pro max kamera depannya jelek ye? Gu...        kamera negatif
# 3    Apple meluncurkan iPhone 11 dengan peningkatan...       baterai positif
# 4    xs max, senderrr. tapi rugi sih kalo kamu beli...  spesifikasi  positif
# ..                                                 ...                   ...
# 743  ga keren banget masa charger bawaannya belum f...       baterai negatif
# 744  yaelah belum fast charging, lama nih kalo ngec...       baterai negatif
# 745  butuh waku lama buat ngecharge kalo pake charg...       baterai negatif
# 746  udah mahal begini masa chargernya blm fast cha...       baterai negatif
# 747  kapasitas baterainya masih kalah dibanding pro...       baterai negatif
#
#                                           Tweet_Parsed
# 0           admin normal pakai baterai kapasitas turun
# 1                                          kamera beda
# 2    kamera depannya jelek liat liat pengguna foto ...
# 3    meluncurkan peningkatan daya tahan baterai leb...
# 4    rugi beli maksud langsung tidak speknya lebih ...
# ..                                                 ...
# 743  tidak keren charger bawaannya belum cepat charger
# 744  yaelah belum cepat charger charge charger bawa...
# 745        butuh waku charge charger bawaan daya kecil
# 746   udah mahal chargernya belum cepat charger kecewa
# 747  kapasitas baterainya kalah dibanding produk le...
#
# [748 rows x 3 columns]

# %%
lexi = pd.read_csv("../data/lexicon/lexiinset_final.csv", sep=";")
lexi
# Out:
#                  word  weight
# 0                 hai       3
# 1             merekam       2
# 2           ekstensif       3
# 3           paripurna       1
# 4              detail       2
# ...               ...     ...
# 10213  kantong kering      -4
# 10214       penggaruk      -3
# 10215         senewen      -4
# 10216      menetapkan      -5
# 10217    kacang botor      -3
#
# [10218 rows x 2 columns]

# %%
def klasifikasi(text, lexicon):
    weight = 0
    for i in range(5):
        n = i+1
        n_grams = [str(text).split(' ')[i-(n-1):i+1] for i in range(n-1,len(str(text).split(' ')))]
        for j in n_grams:
            text_grams = ' '.join(j)
            for k in lexicon:
                if text_grams==k[0]:
                    weight = weight+k[1]
#     weight = ' '.join(map(str, text))
    return weight

# %% [markdown]
# # aspect extraction

# %%
dataset = pd.read_csv("../data/dataset/datasetpraproses.csv", sep=';')

# %%
subaspect = pd.read_csv("../data/dataset/newsubaspect.csv", sep=";")

# %%
subaspect
# Out:
#          aspect  subaspect
# 0       baterai        mah
# 1       baterai  kapasitas
# 2       baterai       daya
# 3       baterai     charge
# 4       baterai    charger
# ..          ...        ...
# 76  spesifikasi     memori
# 77  spesifikasi     sistem
# 78  spesifikasi  processor
# 79        harga      bayar
# 80  spesifikasi  prosessor
#
# [81 rows x 2 columns]

# %%
lexi = pd.read_csv("../data/lexicon/lexiinset_final.csv", sep=";")

# %%
dataset.head()
# Out:
#                                                Tweet                 label  \
# 0  Min, normal ke kalau iPhone 11/11 Pro /Pro Max...       baterai negatif
# 1                         Kmera iphone 11 mmeng beda        kamera positif
# 2  Iphone 11 pro max kamera depannya jelek ye? Gu...        kamera negatif
# 3  Apple meluncurkan iPhone 11 dengan peningkatan...       baterai positif
# 4  xs max, senderrr. tapi rugi sih kalo kamu beli...  spesifikasi  positif
#
#                                         Tweet_Parsed
# 0         admin normal pakai baterai kapasitas turun
# 1                                        kamera beda
# 2  kamera depannya jelek liat liat pengguna foto ...
# 3  meluncurkan peningkatan daya tahan baterai leb...
# 4  rugi beli maksud langsung tidak speknya lebih ...

# %%
label = []
label_score = []
for i in dataset['Tweet_Parsed'].values:
    split = i.split(" ")
    n = len(split)
    start = 0
    j = start
    sentiment = []
    sentiment_score = []
    aspect_temp = []
    zero_score = []
    while start<n and j<n:
        score = 0
        if split[j] in subaspect['subaspect'].values:
            aspect = subaspect[subaspect['subaspect']==split[j]]['aspect'].values[0]
            if j==start:
                k = j+1
                while k<n:
                    if split[k] in subaspect['subaspect'].values:
                        break
                    k = k+1
                opinion = " ".join(split[j:k])
                score = klasifikasi(opinion,lexi.values)
                start = k
            elif j>start:
                k = j
                opinion = " ".join(split[start:k+1])
                score = klasifikasi(opinion,lexi.values)
                start = j+1
                if score==0 and j!=n-1:
                    k = j+1
                    while k<n:
                        if split[k] in subaspect['subaspect'].values:
                            break
                        k = k+1
                    opinion = " ".join(split[j:k])
                    score = klasifikasi(opinion,lexi.values)
                    start = k
            lab_score = "positif" if score>=0 else "negatif"
            if score != 0:
                if aspect not in aspect_temp:
                    sentiment.append(" ".join([aspect,lab_score]))
                    sentiment_score.append(" ".join([aspect,str(score)]))
                aspect_temp.append(aspect)
            else:
                if aspect not in zero_score:
                    zero_score.append(aspect)
            j = start
        else:
            j = j+1
    if len(sentiment) == 0 and len(zero_score) == 0:
        aspect = "general"
        score = klasifikasi(i,lexi.values)
        lab_score = "positif" if score >= 0 else "negatif"
        sentiment.append(" ".join([aspect,lab_score]))
        sentiment_score.append(" ".join([aspect,str(score)]))
    if len(zero_score) > 0:
        for l in zero_score:
            if l not in aspect_temp:
                score = 0
                lab_score = "positif"
                sentiment.append(" ".join([l,lab_score]))
                sentiment_score.append(" ".join([l,str(score)]))
    label.append(",".join(sentiment))
    label_score.append(",".join(sentiment_score))

# %%
# label_score
len(label_score)
# Out:
# 748

# %%
len(label)
# Out:
# 748

# %%
dataset['Prediksi']=label
dataset['Prediksi_Score'] = label_score

# %%
dataset
# Out:
#                                                  Tweet                 label  \
# 0    Min, normal ke kalau iPhone 11/11 Pro /Pro Max...       baterai negatif
# 1                           Kmera iphone 11 mmeng beda        kamera positif
# 2    Iphone 11 pro max kamera depannya jelek ye? Gu...        kamera negatif
# 3    Apple meluncurkan iPhone 11 dengan peningkatan...       baterai positif
# 4    xs max, senderrr. tapi rugi sih kalo kamu beli...  spesifikasi  positif
# ..                                                 ...                   ...
# 743  ga keren banget masa charger bawaannya belum f...       baterai negatif
# 744  yaelah belum fast charging, lama nih kalo ngec...       baterai negatif
# 745  butuh waku lama buat ngecharge kalo pake charg...       baterai negatif
# 746  udah mahal begini masa chargernya blm fast cha...       baterai negatif
# 747  kapasitas baterainya masih kalah dibanding pro...       baterai negatif
#
#                                           Tweet_Parsed  \
# 0           admin normal pakai baterai kapasitas turun
# 1                                          kamera beda
# 2    kamera depannya jelek liat liat pengguna foto ...
# 3    meluncurkan peningkatan daya tahan baterai leb...
# 4    rugi beli maksud langsung tidak speknya lebih ...
# ..                                                 ...
# 743  tidak keren charger bawaannya belum cepat charger
# 744  yaelah belum cepat charger charge charger bawa...
# 745        butuh waku charge charger bawaan daya kecil
# 746   udah mahal chargernya belum cepat charger kecewa
# 747  kapasitas baterainya kalah dibanding produk le...
#
#                           Prediksi     Prediksi_Score
# 0                  baterai negatif         baterai -2
# 1                   kamera negatif          kamera -2
# 2                   kamera negatif          kamera -2
# 3                  baterai positif          baterai 3
# 4                    harga negatif           harga -7
# ..                             ...                ...
# 743                baterai negatif         baterai -5
# 744                baterai positif          baterai 2
# 745                baterai negatif         baterai -5
# 746  harga positif,baterai positif  harga 1,baterai 0
# 747  baterai positif,harga positif  baterai 3,harga 1
#
# [748 rows x 5 columns]

# %%
dataset.to_csv("../data/prediksi/prediksi_inset.csv", sep=";", index=False)
