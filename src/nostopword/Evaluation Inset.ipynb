# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../../data/prediksi/prediksi_inset_nostop.csv", sep=";")

# %%
data
# Out:
#                                                  Tweet  \
# 0    Min, normal ke kalau iPhone 11/11 Pro /Pro Max...
# 1                           Kmera iphone 11 mmeng beda
# 2    Iphone 11 pro max kamera depannya jelek ye? Gu...
# 3    Apple meluncurkan iPhone 11 dengan peningkatan...
# 4    xs max, senderrr. tapi rugi sih kalo kamu beli...
# ..                                                 ...
# 743  ga keren banget masa charger bawaannya belum f...
# 744  yaelah belum fast charging, lama nih kalo ngec...
# 745  butuh waku lama buat ngecharge kalo pake charg...
# 746  udah mahal begini masa chargernya blm fast cha...
# 747  kapasitas baterainya masih kalah dibanding pro...
#
#                                  label  \
# 0                      baterai negatif
# 1                       kamera positif
# 2                       kamera negatif
# 3                      baterai positif
# 4    spesifikasi positif,harga positif
# ..                                 ...
# 743                    baterai negatif
# 744                    baterai negatif
# 745                    baterai negatif
# 746                    baterai negatif
# 747                    baterai negatif
#
#                                           Tweet_Parsed  \
# 0    admin normal ke kalau     baru pakai beberapa ...
# 1                                  kamera  memang beda
# 2       kamera depannya jelek  aku liat liat para p...
# 3     meluncurkan  dengan peningkatan daya tahan ba...
# 4       tapi rugi  kalau kamu beli   baru sekarang ...
# ..                                                 ...
# 743  tidak keren sekali masa charger bawaannya belu...
# 744  yaelah belum cepat charger lama  kalau charge ...
# 745  butuh waku lama buat charge kalau menggunakan ...
# 746  udah mahal begini masa chargernya belum cepat ...
# 747  kapasitas baterainya masih kalah dibanding pro...
#
#                               Prediksi           Prediksi_Score
# 0                      baterai negatif               baterai -4
# 1                       kamera positif                 kamera 0
# 2                       kamera negatif                kamera -3
# 3                      baterai positif                baterai 3
# 4    spesifikasi negatif,harga negatif  spesifikasi -9,harga -1
# ..                                 ...                      ...
# 743                    baterai negatif               baterai -6
# 744                    baterai negatif               baterai -5
# 745                    baterai negatif               baterai -8
# 746      harga positif,baterai negatif       harga 1,baterai -1
# 747      baterai positif,harga positif        baterai 3,harga 1
#
# [748 rows x 5 columns]

# %%
class eval:
    def __init__(self):
        pass
    
    def aspect_count(self,data, aspect, label_col = 'label'):
        label_list = data[label_col].values
        pos, neg = 0, 0
        for i in label_list:
            split = i.split(",")
            for j in split:
                in_split = j.split(" ")
                if in_split[0] == aspect:
                    if in_split[1] == 'negatif':
                        neg = neg+1
                    else:
                        pos = pos+1
        return pos,neg
    
    def eval_count(self,data,true_label_col='label',pred_label_col='Prediksi',aspect_list=['general','spesifikasi','kamera','baterai','harga']):
        label_list = [str(i).split(",") for i in data[true_label_col].values]
        pred_list = [str(i).split(",") for i in data[pred_label_col].values]
        sent = ['positif','negatif']
        eval_list = []
        for i in aspect_list:
            for j in range(len(sent)):
                asp_count = self.aspect_count(data,i)
                record = [i,sent[j],asp_count[j]]
                pred_count = 0
                pred_true = 0
                pred_false = 0
                for k,l in zip(label_list,pred_list):
                    if " ".join([i,sent[j]]) in l:
                        pred_count = pred_count+1
                        if " ".join([i,sent[j]]) in k:
                            pred_true = pred_true+1
                        else:
                            pred_false = pred_false+1
                record.extend([pred_count,pred_true,pred_false])
                eval_list.append(record)
        return eval_list
    
    def get_pred_text(self,data,true_label_col='label',pred_label_col='Prediksi',text_col="Tweet",prep_text_col='Tweet_Parsed',predicted = False):
        label_list = data[true_label_col].values
        pred_list = data[pred_label_col].values
        text_list = data[text_col].values
        prep_text_list = data[prep_text_col].values
        pred_text = []
        for i in range(data.shape[0]):
            if predicted == False:
                if label_list[i] != pred_list[i]:
                    pred_text.append([text_list[i],prep_text_list[i],label_list[i],pred_list[i]])
            else:
                if label_list[i] == pred_list[i]:
                    pred_text.append([text_list[i],prep_text_list[i],label_list[i],pred_list[i]])
                
        return pred_text

# %%
evaluate = eval()

# %%
eval_result = evaluate.eval_count(data)
eval_result = pd.DataFrame(eval_result,columns=['aspect','sentiment','label count','predicted count','true predict','false predict'])
eval_result = eval_result.groupby(['aspect','sentiment']).sum()
eval_result['percent_true'] = round((eval_result['true predict']/eval_result['label count'])*100,2)
eval_result['percent_predict_true'] = round((eval_result['true predict']/eval_result['predicted count'])*100,2)
eval_result
# Out:
#                        label count  predicted count  true predict  \
# aspect      sentiment
# baterai     negatif             77              119            58
#             positif             82               45            25
# general     negatif             82              152            56
#             positif            107               99            55
# harga       negatif             79               56            32
#             positif             65               85            42
# kamera      negatif             70               94            43
#             positif            110               82            53
# spesifikasi negatif             62               67            24
#             positif             86               49            31
#
#                        false predict  percent_true  percent_predict_true
# aspect      sentiment
# baterai     negatif               61         75.32                 48.74
#             positif               20         30.49                 55.56
# general     negatif               96         68.29                 36.84
#             positif               44         51.40                 55.56
# harga       negatif               24         40.51                 57.14
#             positif               43         64.62                 49.41
# kamera      negatif               51         61.43                 45.74
#             positif               29         48.18                 64.63
# spesifikasi negatif               43         38.71                 35.82
#             positif               18         36.05                 63.27

# %%
false_tweet = evaluate.get_pred_text(data)
false_tweet = pd.DataFrame(false_tweet,columns=['Tweet','Tweet_Parsed','True_Label','Pred_Label'])
false_tweet
# Out:
#                                                  Tweet  \
# 0    xs max, senderrr. tapi rugi sih kalo kamu beli...
# 1    Saya juga dulu confuse nak pilih iphone 11 or ...
# 2    Kalo sender lebih mentingin ketajaman layar me...
# 3    Cantik babi purple iphone 11 ni sialla apahal ...
# 4    Tidak murah sbb iphone 12 skrin sama besar dgn...
# ..                                                 ...
# 394  iphone11 ini menggunakan chipset terkuat dan t...
# 395  buat iphone 11 ini apple udah mengembangkan te...
# 396  ip11 ini punya teknologi yang bisa menekan pen...
# 397  udah mahal begini masa chargernya blm fast cha...
# 398  kapasitas baterainya masih kalah dibanding pro...
#
#                                           Tweet_Parsed  \
# 0       tapi rugi  kalau kamu beli   baru sekarang ...
# 1    saya juga dulu bingung ingin pilih  atau    re...
# 2    kalau  lebih lebih penting ketajaman layar leb...
# 3           cantik  ungu  ini  padahal aku tidak kaya
# 4    tidak murah karena  layar sama besar dengan   ...
# ..                                                 ...
# 394   ini menggunakan chipset terkuat dan tercepat ...
# 395  buat  ini  udah mengembangkan teknologi khusus...
# 396  ip ini punya teknologi  bisa menekan penggunaa...
# 397  udah mahal begini masa chargernya belum cepat ...
# 398  kapasitas baterainya masih kalah dibanding pro...
#
#                                             True_Label  \
# 0                    spesifikasi positif,harga positif
# 1                                       kamera negatif
# 2    general positif,kamera positif,spesifikasi pos...
# 3                                      general positif
# 4                        harga negatif,general positif
# ..                                                 ...
# 394                                    baterai positif
# 395                                    baterai positif
# 396                                    baterai positif
# 397                                    baterai negatif
# 398                                    baterai negatif
#
#                                             Pred_Label
# 0                    spesifikasi negatif,harga negatif
# 1    spesifikasi negatif,general positif,kamera neg...
# 2    general positif,kamera positif,spesifikasi neg...
# 3                                      general negatif
# 4                        harga negatif,general negatif
# ..                                                 ...
# 394                spesifikasi negatif,baterai negatif
# 395                                    baterai negatif
# 396                baterai positif,spesifikasi negatif
# 397                      harga positif,baterai negatif
# 398                      baterai positif,harga positif
#
# [399 rows x 4 columns]

# %%
true_tweet = evaluate.get_pred_text(data,predicted=True)
true_tweet = pd.DataFrame(true_tweet,columns=['Tweet','Tweet_Parsed','True_Label','Pred_Label'])
true_tweet
# Out:
#                                                  Tweet  \
# 0    Min, normal ke kalau iPhone 11/11 Pro /Pro Max...
# 1                           Kmera iphone 11 mmeng beda
# 2    Iphone 11 pro max kamera depannya jelek ye? Gu...
# 3    Apple meluncurkan iPhone 11 dengan peningkatan...
# 4    Hasil kamera xiaomi note 10 bisa di adulah sam...
# ..                                                 ...
# 344  baterai nya boros, ga cocok buat orang yang pe...
# 345        ngecharge nya butuh watu lama ini iphone 11
# 346  ga keren banget masa charger bawaannya belum f...
# 347  yaelah belum fast charging, lama nih kalo ngec...
# 348  butuh waku lama buat ngecharge kalo pake charg...
#
#                                           Tweet_Parsed       True_Label  \
# 0    admin normal ke kalau     baru pakai beberapa ...  baterai negatif
# 1                                  kamera  memang beda   kamera positif
# 2       kamera depannya jelek  aku liat liat para p...   kamera negatif
# 3     meluncurkan  dengan peningkatan daya tahan ba...  baterai positif
# 4    hasil kamera xiaomi note bisa di adulah sama  ...   kamera positif
# ..                                                 ...              ...
# 344  baterai  boros tidak cocok buat orang  pekerja...  baterai negatif
# 345                      charge  butuh watu lama ini    baterai negatif
# 346  tidak keren sekali masa charger bawaannya belu...  baterai negatif
# 347  yaelah belum cepat charger lama  kalau charge ...  baterai negatif
# 348  butuh waku lama buat charge kalau menggunakan ...  baterai negatif
#
#           Pred_Label
# 0    baterai negatif
# 1     kamera positif
# 2     kamera negatif
# 3    baterai positif
# 4     kamera positif
# ..               ...
# 344  baterai negatif
# 345  baterai negatif
# 346  baterai negatif
# 347  baterai negatif
# 348  baterai negatif
#
# [349 rows x 4 columns]

# %%
eval_result.to_csv("../../data/final/evalresult_inset_nostop.csv", sep=";", index=False)
false_tweet.to_csv("../../data/final/falsetweet_inset_nostop.csv", sep=";", index=False)
true_tweet.to_csv("../../data/final/truetweet_inset_nostop.csv", sep=";", index=False)
